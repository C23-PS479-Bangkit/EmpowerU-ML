# %% [markdown]
# # Bangkit 2022 Capstone Project
# This project aims to classify the sentiment of a text as either positive or negative. It involves transfer learning using IndoBERT. The data collection is done through a combination of semi-manual scraping, automated scraping, and open data from the internet.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from transformers import BertTokenizer, TFBertModel

# %% [markdown]
# ### Training data preprocessing:

# %%
df_gmaps = pd.read_csv("./data/google_maps.csv")
df_tokped = pd.read_csv("./data/dataset_review_tokped_labelled.csv")

df_tokped.head()
# Out:
#                                               Review  Rating Sentiment
# 0                                      enak kuacinya       5  positive
# 1  pengiriman cepat packing bagus sesuai pesanan ...       5  positive
# 2  pengemasan luar biasa baik untuk rasa menurut ...       4  negative
# 3                                    terimakasih min       5   neutral
# 4                 udah order untuk kesekian kali jos       5   neutral

# %%
df_tokped.drop("Rating", axis="columns", inplace=True)
df_tokped.head()
# Out:
#                                               Review Sentiment
# 0                                      enak kuacinya  positive
# 1  pengiriman cepat packing bagus sesuai pesanan ...  positive
# 2  pengemasan luar biasa baik untuk rasa menurut ...  negative
# 3                                    terimakasih min   neutral
# 4                 udah order untuk kesekian kali jos   neutral

# %%
df_tokped.columns = ["text", "label"]
df_tokped.head()
# Out:
#                                                 text     label
# 0                                      enak kuacinya  positive
# 1  pengiriman cepat packing bagus sesuai pesanan ...  positive
# 2  pengemasan luar biasa baik untuk rasa menurut ...  negative
# 3                                    terimakasih min   neutral
# 4                 udah order untuk kesekian kali jos   neutral

# %%
# change "positive" or "neutral" to 1, change "negative" to 0
df_tokped["label"] = df_tokped["label"].map(lambda row: 0 if row == "negative" else 1)
df_tokped.head()
# Out:
#                                                 text  label
# 0                                      enak kuacinya      1
# 1  pengiriman cepat packing bagus sesuai pesanan ...      1
# 2  pengemasan luar biasa baik untuk rasa menurut ...      0
# 3                                    terimakasih min      1
# 4                 udah order untuk kesekian kali jos      1

# %%
df_tokped["label"].value_counts()
# Out:
# 1    3488
# 0     572
# Name: label, dtype: int64

# %%
df = pd.concat([df_gmaps, df_tokped], ignore_index=True)

df.head()
# Out:
#                                                 text  label
# 0  Tempat yang enak untuk hang out bersama teman ...      1
# 1  Tempatnya nyaman krn smoking areanya benar2 te...      1
# 2  Tempat ternyaman dan deket banget sama kantor....      1
# 3  Tempatnya luas bgtt, nyaman kalo buat nugas ku...      1
# 4  Tempatnya cukup luas. Bisa blocking. Instagram...      1

# %% [markdown]
# ### Train test split

# %%
# shuffle training data
df = df.sample(frac=1, ignore_index=True)

df.head()
# Out:
#                                                 text  label
# 0                            agak lama sih ngirimnya      0
# 1                kurang sedap kurang kerasa ikan nya      0
# 2       selesai dgn baik dan dpt bonus pie tq seller      1
# 3  pengiriman cepat sesuai pesanan recommended se...      1
# 4                                 ada bonus nya juga      1

# %%
# train-valid-test split 70-20-10
train_size = int(len(df) * 0.7)
valid_size = int(len(df) * 0.2)

df_train = df[:train_size]
df_valid = df[train_size:train_size + valid_size]
df_test = df[train_size + valid_size:]

print(len(df_train))
print(len(df_valid))
print(len(df_test))
# Out:
# 2982
# 852
# 426

# %%
x_train = df_train["text"].values
y_train = df_train["label"].values

x_valid = df_valid["text"].values
y_valid = df_valid["label"].values

x_test = df_test["text"].values
y_test = df_test["label"].values

# %% [markdown]
# ### Modelling

# %%
# download the IndoBERT pre-trained model
model_name='cahya/bert-base-indonesian-522M'
bert_tokenizer = BertTokenizer.from_pretrained(model_name)
bert_model = TFBertModel.from_pretrained(model_name)
bert_model.trainable = False
# Out:
# Some layers from the model checkpoint at cahya/bert-base-indonesian-522M were not used when initializing TFBertModel: ['mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at cahya/bert-base-indonesian-522M.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
# tokenize the training data using bert tokenizer
x_train_tokenized = bert_tokenizer(x_train.tolist(), truncation=True, max_length=100, padding=True, return_tensors="tf")
x_valid_tokenized = bert_tokenizer(x_valid.tolist(), truncation=True, max_length=100, padding=True, return_tensors="tf")
x_test_tokenized = bert_tokenizer(x_test.tolist(), truncation=True, max_length=100, padding=True, return_tensors="tf")

# %% [markdown]
# ### Evaluation

# %%
# Load the TFLite model
interpreter = tf.lite.Interpreter(model_path="model.tflite")
interpreter.allocate_tensors()

# Get the input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Prepare the input data
x_test_tokenized_input = x_test_tokenized.input_ids.numpy()

# Perform the prediction
predictions = []
for i in range(len(x_test_tokenized_input)):
    input_data = x_test_tokenized_input[i]
    input_data = input_data.reshape(1, -1)
    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()
    output_data = interpreter.get_tensor(output_details[0]['index'])
    predictions.append(output_data[0][0])

# Convert the predictions to binary labels
predictions = np.array(predictions)
binary_predictions = np.round(predictions).astype(int)

# Print the predictions
for i in range(len(x_test)):
    print(f"Review: {x_test[i]}")
    print(f"Predicted Label: {binary_predictions[i]}")
    print()
# Out:
# Review: second order
# Predicted Label: 1
#
# Review: barangnya puas
# Predicted Label: 1
#
# Review: pertama kali beli disini respon dan pengiriman cepat packing pun rapi dengan dibungkus double dan aman terima kasih
# Predicted Label: 1
#
# Review: tlong di beri rasa yg beda2 bbrp kali order dpt nya rasa itu2 aja
# Predicted Label: 0
#
# Review: puas bgt belanja jus disini pengiriman rapi dan cepat seller sgt ramah dan selalu membalasa chat dgn cepat hrg pun murah pokoknya pelayanannya bagus rekomen bgt beli disini
# Predicted Label: 1
#
# Review: Tempat sdh bagus sayang di sayang pelayanan nya gak bagus,👎👎👎👎, Gak bisa order saat pergantian shift, lama sekali kebanyakan bercanda, terlalu cuek terhadap customer
# Predicted Label: 1
#
# Review: bagus semoga kwalitas tetap di utamakan biar jadi langganan tetap
# Predicted Label: 1
#
# Review: semua item sesuai orderan seperti biasa selalu prosesnya cepat packing dan kirim rapi untuk rasa dan kualitas rotinya keluarga kita cocok chewy tp lembut teksturnya challa selalu masuk item yg diorder setiap belanja di sinu thaaanks n sukses selalu
# Predicted Label: 1
#
# Review: senantiasa enak kue tart ter favorit saat ini
# Predicted Label: 1
#
# Review: sesuai trm ksh
# Predicted Label: 1
#
# Review: original mantapp pengiriman cepat
# Predicted Label: 1
#
# Review: nasi nya tidak keras dan lauknya enak2 untungnya order yg premium krn porsinya kurang klo menurut saya tapi overall puas dengan order ini terima kasih
# Predicted Label: 1
#
# Review: packing sangat bagus sampai di tujuan dengan baik terinya gurih enak bener
# Predicted Label: 1
#
# Review: semua produk disini selalu okay
# Predicted Label: 1
#
# Review: pengiriman cepat pakai kardus dan bubble wrap mantap
# Predicted Label: 1
#
# Review: a
# Predicted Label: 1
#
# Review: enak neh psg molennya packing rapi thks yah
# Predicted Label: 1
#
# Review: keripik agak hancur tp kayanya dari pabriknya ini okay sih secara umum
# Predicted Label: 0
#
# Review: pengemasannn nyaa cepett bgttt pesen kmrn sekaranggg sampeee makasiiii seller
# Predicted Label: 1
#
# Review: its ok
# Predicted Label: 1
#
# Review: packaging rapih dan barangnya sesuai hanya saja pengirimannya lumayan lama padahal lokasi berdekatan next semoga bisa diperbaiki
# Predicted Label: 1
#
# Review: puas pokoknya
# Predicted Label: 1
#
# Review: barang mantabs order yg ke 2 thanks gan
# Predicted Label: 1
#
# Review: enak gak keras
# Predicted Label: 1
#
# Review: kurang sukaa jujur rasanya kurang cocok di aku tp pengiriman baik sih
# Predicted Label: 1
#
# Review: rasanya enak sekali pengiriman cepat sampainya dan kurirnya ramah terimakasih ya
# Predicted Label: 1
#
# Review: respons cepat sebahagian sdh melempem
# Predicted Label: 1
#
# Review: respon pengiriman paket aman sampai rmh mksh seller n abang gosendnya
# Predicted Label: 1
#
# Review: barang tiba dgn aman baru akan dicoba semoga laris jualan ya
# Predicted Label: 1
#
# Review: barang di terima dgn baik semoga cocok produk nya terima kasih
# Predicted Label: 1
#
# Review: seller ramah responsif sangat membantu jadi komunikasi nya enak packing rapi dan pengiriman cepat repeat order sih ini
# Predicted Label: 1
#
# Review: sdh diminum smg bermaafaat tks
# Predicted Label: 1
#
# Review: puas srkali memang gak lama sampai tapi kemarin baru sekarang kasih ulasan kurir ramah dan baik terima kasih toko pedia
# Predicted Label: 1
#
# Review: pengirimannya cepat sekali pagi pesan siangnya sudah sampai produk aman rasanya enak terimakasih
# Predicted Label: 1
#
# Review: barang sesuai pesanan pengiriman cepat dan aman thanks seller
# Predicted Label: 1
#
# Review: terima kasih tokopedia bintang yg bicara
# Predicted Label: 1
#
# Review: Tempatnya cozy banget, variasi makanannya banyak, dan ada gelato nya juga. Mbak Mas nya ramah, baru masuk langsung di sapa. Murah senyum juga. untuk ordernya lewat barcode, buat saya pribadi ini sangat mudah, kalo sudah di order waiters nya bakalan make sure lagi ke meja kita dan bacain ulang pesanannya.
# Predicted Label: 1
#
# Review: brg sesuai deskripsi kualitas bgs respon cepat n packaging rapi recommended
# Predicted Label: 1
#
# Review: barang nya sesuai pesanan dan proses nya cepat
# Predicted Label: 1
#
# Review: makanan kesukaan sejak kecil sudah 2x beli lewat toped packing rapi aman
# Predicted Label: 1
#
# Review: agak kecewa mesen cappucino no sugar tapi dikasih gula, rasa kopinya kurang banget kayaknya harus minta double shoot. pelayananya kurang ramah ya, cukup sekali kayaknya kesini
# Predicted Label: 1
#
# Review: terima nya kurangbagus
# Predicted Label: 1
#
# Review: pelayanan cepat dan ramah
# Predicted Label: 1
#
# Review: thanks barang sdh dtg cepat n rapih packing nya sukses selalu
# Predicted Label: 1
#
# Review: mantaplah pokoknya
# Predicted Label: 1
#
# Review: respond dari penjual yg sangat membantu dlm proses pengorderan carrot cakenya juga mantap
# Predicted Label: 1
#
# Review: good product sesuai deskripsi recommended product
# Predicted Label: 1
#
# Review: enak bgt cakenya admin juga fast respon makasih ya
# Predicted Label: 1
#
# Review: halo kak makasih ya cemilannya sudah sampai seperti biasa packing aman dan rapi free bubble dan kardus karena itu gak ada yang hancur untuk rasa belum di coba hehe semoga enak
# Predicted Label: 1
#
# Review: pengiriman cepat packing rapi kurir baik next order lg trm ksh seller dan tokopedia
# Predicted Label: 1
#
# Review: kerupuknya sudah sampai tapi belum di goreng mudah2an mekar dan enak rasanya
# Predicted Label: 1
#
# Review: good barang enak
# Predicted Label: 1
#
# Review: di terima dgn selamat gak ada yg hancur ato patah pengiriman standar ya 2 hari sampai
# Predicted Label: 1
#
# Review: pelayanan nya cepat n bungkusnya rapih
# Predicted Label: 1
#
# Review: enak jahenya berasa banget
# Predicted Label: 1
#
# Review: ini uda beli yang kesekian kali bawang gorengnya enak banget
# Predicted Label: 1
#
# Review: Pelayanan yang sangat buruk, tidak peduli terhadap pembeli. Merendahkan pelanggan
# Predicted Label: 1
#
# Review: repeat order dan msh tetep sukaaaaaa enak bgt deh selain sehat ada yakult nya ada rasa nya juga jd itu yg buat tambah enakkkk terima kasih
# Predicted Label: 1
#
# Review: pesen semalem bsk siang sampe
# Predicted Label: 1
#
# Review: selalu beli disini respon cepat pokoknya mantab beli disini
# Predicted Label: 1
#
# Review: terima kasih ya pesananku udah sampe nihh baru dibuka satu udah langsung di foto
# Predicted Label: 1
#
# Review: ga pake lama bayar langsung kirim mantep deh bosquee
# Predicted Label: 1
#
# Review: cake nya enak meski menurut saya manis diatas biasa nya
# Predicted Label: 1
#
# Review: pesanan diterima dalam keadaan fresh dan dikemas dg rapi sangat bersih dan aman sangat recomended
# Predicted Label: 1
#
# Review: biasa aja rasanya tapi penjualnya baik ramah semoga berkah ya
# Predicted Label: 1
#
# Review: tq
# Predicted Label: 1
#
# Review: pas untuk dikemut
# Predicted Label: 1
#
# Review: respon seller baik dan pengiriman tepat waktu packing sangat baik dan aman jgn ragu deh belanja disini
# Predicted Label: 1
#
# Review: ujungnya kering jadi bintang 3 aja deh yak
# Predicted Label: 1
#
# Review: prod sdh diterima dg baik tx
# Predicted Label: 1
#
# Review: pelayanan memuaskan
# Predicted Label: 1
#
# Review: mantap pedasnya luar biasa
# Predicted Label: 1
#
# Review: recommended product one of the best choipans yang pernah saya pesan secara online seller ramah dan komunikatif
# Predicted Label: 1
#
# Review: sudah 2 kali pesan di sini benar2 enak deh
# Predicted Label: 1
#
# Review: pelayanan top komunikasi bagus barang sehari sampai packingnya aman barang sesuai deskripsi recommended seller
# Predicted Label: 1
#
# Review: rasa nya memuaskan gurih sedikit pedas sekilas rasa manis tinggal asam nya ditambah saya sengaja beli fresh supaya bisa atur kadar keasaman nya sendiri enak sayurnya segar dan crunchy berikut pasti beli lagi kimchi sehat banget ini makanan probiotik alami
# Predicted Label: 1
#
# Review: barang cepat sampai n penjual responsif
# Predicted Label: 1
#
# Review: mantap rekomended
# Predicted Label: 1
#
# Review: pengirimannya cepat meskipun pake free ongkir
# Predicted Label: 1
#
# Review: mantap dan enak pelayanan juga super cepat dan ramah recommened seller terima kasih
# Predicted Label: 1
#
# Review: respon baik pengiriman cepat di hari minggu
# Predicted Label: 1
#
# Review: produk sampai dg aman sesuai dan msh lama expired lumayan cepat pengirman
# Predicted Label: 1
#
# Review: packing oke kualitas ok cuma lama di ekspedisi mungkin krn menjelang lebaran
# Predicted Label: 1
#
# Review: pokoknya ga bs2 berkata2 deh uenaaknya polll dijamin ketagihan nih
# Predicted Label: 1
#
# Review: barang ok banget lezat dan tetap krispi renyah
# Predicted Label: 1
#
# Review: kembali ke awal rasanya
# Predicted Label: 1
#
# Review: toko terpercaya sejak 3 tahun kebelakang mantap pokonya
# Predicted Label: 1
#
# Review: ga sesuai dengan gambar soal rasa standar banget
# Predicted Label: 1
#
# Review: packing aman sekali bubble wrap tebal sayang nya belum bisa coba karna sedang kena covid indra perasa masih kacau
# Predicted Label: 1
#
# Review: bawangnya enak kriuk pengiriman cepat
# Predicted Label: 1
#
# Review: Pelayananya lama. Udah tau penuh karyawan cuma 2 orang. Saya udah antri 30 menit haduh lama.
# Predicted Label: 1
#
# Review: tumben rada asin sedikit dr biasanya hehe
# Predicted Label: 1
#
# Review: hallo maaf ya baru bikin ulasan coca cola zero telah diterima sejak senin n makasih telah memjadi supplier minuman kami yg mengirim barang tepat waktu
# Predicted Label: 1
#
# Review: enaaaaakkkkk uda langganan beli disini uda gak mao pindah2 kelain hatiii gak percaya buktiin sendiri ajeee ya man teman
# Predicted Label: 1
#
# Review: barang sesuai diskripsi pengirimn jg cepat thxxx
# Predicted Label: 1
#
# Review: barang sesuai deskripsi enak tp proses pengiriman nya lambat padahal dah pake same day pesan jam 12 tp baru kirim esoknya
# Predicted Label: 1
#
# Review: wah cepat sekali sampainya nih baru pertama kali beli mudah mudahan cocok nih terimakasih
# Predicted Label: 1
#
# Review: barang sesuai spesifikasi
# Predicted Label: 1
#
# Review: enak rasanya manis pedas terinya dibanyakin lagi dong
# Predicted Label: 0
#
# Review: saya sangat puas mulai dari respon layananan keramahan dan dekorasi kuex sangat puas tuhan berkati usaha pelapak dan semoga bisa selalu membawa kebahagiaan bagi siapa saja yang memesan kue di toko ini bintang 100000000000 kualitas 100000000
# Predicted Label: 1
#
# Review: penjual responnya cepat pengiriman walaupun pake grabbike aman dan rapi banget produknya sesuai harapan dan rasanya enyaaak makasiiih yaah semoga sukses dan bakal repeat order produk2 lain makasih
# Predicted Label: 1
#
# Review: respon baik packaging sangat rapi
# Predicted Label: 1
#
# Review: harga kompetitir rasanya enak
# Predicted Label: 1
#
# Review: layanan
# Predicted Label: 1
#
# Review: proses cepat packing rapi
# Predicted Label: 1
#
# Review: proses dan pengiriman bgs respon seller ok produk yg dijual enak2
# Predicted Label: 1
#
# Review: seller gercep enak pia nya uda sering beli sukses terus
# Predicted Label: 1
#
# Review: seperti biasanya belanja disini selalu memuaskan recommended seller
# Predicted Label: 1
#
# Review: oke banget sesuai dengan pesanan
# Predicted Label: 1
#
# Review: pengiriman secepat kilat belum dicoba rasanya karena belum buka puasa
# Predicted Label: 1
#
# Review: enak bangett burnt cheese cake nya suka sekali pas semua nya
# Predicted Label: 1
#
# Review: pengiriman cepat rasanya enak
# Predicted Label: 1
#
# Review: packing cepat aman rapi barang sampai dg selamat kualitas ok
# Predicted Label: 1
#
# Review: bawang goreng nya renyah
# Predicted Label: 1
#
# Review: pesanan sesuai kurir cepat dan rapi
# Predicted Label: 1
#
# Review: mantaappp
# Predicted Label: 1
#
# Review: tq seller ramah n responsif banged pengiriman super cepat packaging aman tq
# Predicted Label: 1
#
# Review: kemasan bagus rapi n aman jadi langganan terussss
# Predicted Label: 1
#
# Review: as always the best
# Predicted Label: 1
#
# Review: kemasan yg bagus
# Predicted Label: 1
#
# Review: kamsiya
# Predicted Label: 1
#
# Review: pesanan sdh diterima dgn baik pelayanan dan pengiriman cepat terimakasih yaaa
# Predicted Label: 1
#
# Review: second order highly recommended the best basque cheesecake in the town
# Predicted Label: 1
#
# Review: pengiriman cepat pake instant no drama tapi kenapa begitu dibuka aromanya kayak basi gitu tetapi pas dimakan baik baik aja sih ini orderan kedua kali dan rasanya konsisten
# Predicted Label: 1
#
# Review: gemeshhh bgtdpt 2 paperbag ma kartuny
# Predicted Label: 1
#
# Review: biarkan tangan yg bicara mantul rasa saladnya
# Predicted Label: 1
#
# Review: barang sesuai deskripsi enakk dan lezat semoga makin sukses dan untung y bos
# Predicted Label: 1
#
# Review: burnt cheesecakenya enak rasanya pas gak kemanisan n bisa dimakan dalam jumlah banyak respon cepet n pengantarannya juga cepet thanks ergu
# Predicted Label: 1
#
# Review: puas banget ikannya bagus kering dan bisa langsung di olah bakal langganan keliatannya makasih yaaaa
# Predicted Label: 1
#
# Review: love so much taste good and healthy as well
# Predicted Label: 1
#
# Review: sesuai gn gambar pengiriman sgt cpt
# Predicted Label: 1
#
# Review: masih enak seperti dulu tapi sayang terkocok waktu pengiriman jadi gepeng gepeng
# Predicted Label: 1
#
# Review: ntah yg ke berapa kali beli di sini dan selalu puas dan happy
# Predicted Label: 1
#
# Review: terima kasih barang sdh diterima dengan baik
# Predicted Label: 1
#
# Review: pengalaman terburuk di tahun 2020 , apartemen green lake view mati listrik , mati air, harus naik turun lewat tangga gilaa bro saya di lantai 12 kaki gempor uda 2 hari ngga ada info apa hidup atau ngga nya gimnaa ini penangannya managementnya parah betul sangat sangat kecewaaaaaaa. uda tau alasannya basement banjir yaang gimnaa laah kasih kita air bersih buat mandi ngga ada apun deh kecewa
# Predicted Label: 0
#
# Review: selalu puas recomended banget
# Predicted Label: 1
#
# Review: lumayan
# Predicted Label: 1
#
# Review: Pengalaman kurang menyenangkan, toiletnya tidak ada air, tunggu keluarnya lama sekali dan itu pun sangat sangat kecil sekali menampungnya pun hanya dapat 1 gayung kurang, itu terjadi ketika mau membilas habis BAB, bayangkan paniknya bagaimana
# Predicted Label: 0
#
# Review: enak cookiesnya pengiriman cepat dan aman
# Predicted Label: 1
#
# Review: packing rapi produk ok exp masih lama selalu puas belanja di sini recomended seller
# Predicted Label: 1
#
# Review: saya beli untuk kantor n pada suka makanya repeat terus trims ya
# Predicted Label: 1
#
# Review: belom dicoba tapi keliatannya enak dan besar2
# Predicted Label: 1
#
# Review: enaaaakk renyah
# Predicted Label: 1
#
# Review: almond madunya spt homemade biasa lengket bngt dan kurang garing tdk spt honey almond yg normal dibeli di toko2 kecewa bngt apalagi stlh pengirimannya lama bngt 3 hr stlh pesan baru dikirim not recommended sorry yah
# Predicted Label: 1
#
# Review: order sesuai pesanan
# Predicted Label: 1
#
# Review: alhamdulillah paket sudah sampai dgn selamat terima kasih kk smoga lancar usahanya aamiin
# Predicted Label: 1
#
# Review: rasa memuaskan harga murah kualitas luar biasa ditambah ada bonus puding
# Predicted Label: 1
#
# Review: kondisi baik kurir baik mdh2an enak terimakasih
# Predicted Label: 1
#
# Review: maaf ya barangnya tidak diterima
# Predicted Label: 1
#
# Review: cepat sampai tapi kok keras bgt yaaa
# Predicted Label: 1
#
# Review: mudah2an gk bosan dengn tekstur pdng nya
# Predicted Label: 1
#
# Review: enak2 semua manisnya pas terutama yg varian greentea nya grenteacheese nya tebal dan coklatnya enak
# Predicted Label: 1
#
# Review: pas awal nyampe sempet ada semut kecil gitu di luar paketnya terus saran aja sih tolong di segel tutup nya soalnya ga kenceng bgt gampang dibuka takut pecah aja berantakan soalnya ga ada bubblewrap nya klo segi isi sih ga begitu full tapi gatau rasanya enak apa engga belum di coba tolong perbaiki packingnya ya
# Predicted Label: 0
#
# Review: paking rapi pengiriman cepat rasa oke
# Predicted Label: 1
#
# Review: this is the way
# Predicted Label: 1
#
# Review: pengirimannya lama bangettt tpi barangnya bagusss sedihnya yg matcha kek ga full gitu isinya ga tau deh
# Predicted Label: 1
#
# Review: proses cepat dan barang sesuai
# Predicted Label: 1
#
# Review: barangnya mantap ada lebih lebihnya recomended
# Predicted Label: 1
#
# Review: blm dicoba
# Predicted Label: 1
#
# Review: ok cpt pengirimannya
# Predicted Label: 1
#
# Review: biar bintang yg berbicara pokoknya mantap deh
# Predicted Label: 1
#
# Review: terima kasih banyak telah melayani dengan baik semua products bagus packaging nya aman products sesuai foto harga bersaing dengan bagus pengiriman cepat tepat very recommended shop seller next pasti akan sering blanja lagi di sini deh semoga semakin maju sukses ya
# Predicted Label: 1
#
# Review: repurchase untuk kesekian kalinya secinta itu emang sama seleros madu
# Predicted Label: 1
#
# Review: enak rasanya sesuai yang emang lagi dicari cepet dikirim
# Predicted Label: 1
#
# Review: Saya benar benar emosi sama staff sana. Sisaan gosong sedikit bgt disuruh makan yg sudah kotor Sedikit bgt dikumpulin Terkecuali kami buang buang makanan dalam masih berbentuk utuh dan byk. Ini semua habis kami buat. Kami makan beramai ramai dan tau etika ambil makanan sedikit sedikit. Karna kami ga sekali dua kali makan seperti ini dan tidak hanya di omg saja.. Kami benar benar kecewa dengan pelayanan di kelapa gading. Tolong staff disana ditegur supaya melayani kami dengan baik. Karna kami merasa tidak dihargai makan disana.
# Predicted Label: 0
#
# Review: biasa aja saus nya kurang masuk
# Predicted Label: 1
#
# Review: harga murah packing aman bgt pengiriman aja yg rada lams
# Predicted Label: 1
#
# Review: sudah langganan setahun lebih cocok belanja disini tokonya amanah baarakallahu fiik
# Predicted Label: 1
#
# Review: ikan fresh bagus kemasan juga baik haya aroma asapnya kurang keluar tp yah okay lah
# Predicted Label: 1
#
# Review: seller nya ramah cepat respon sehingga barang pun cepat sampai terima kasih sehat selalu
# Predicted Label: 1
#
# Review: dendengnya asiiin maaf setahu saya dendeng itu manis asam
# Predicted Label: 1
#
# Review: semua produknya selalu bagus dan segar moga laris manis dan sehat selalu kakak terima kasih
# Predicted Label: 1
#
# Review: semua barang selalu sesuai gambar dan deskripsi
# Predicted Label: 1
#
# Review: enakkkkkks syekali makasi seller makasi jga abang kurir
# Predicted Label: 1
#
# Review: udah beli yang kedua kalinya disini bakal terus jd langganan
# Predicted Label: 1
#
# Review: kurang 250ml hanya 3 gelas
# Predicted Label: 1
#
# Review: llelelelellelelelelelellelelelelelelelelelelelelelelelelele
# Predicted Label: 1
#
# Review: Lokasi cafenya persis di pinggir jalan, memang lumayan akses kesini terutama dari depok yg persis perbatasan cibubur. Enak tempatnya buat nongkrong, makanan dan minumannya jg bervariasi. Tempat parkir cukup 4 mobil dan motor lumayan besar. Kebetulan cafe ini jadi saksi sejarah perayaan 1th anniversary komunitas sepeda yg saya ikuti
# Predicted Label: 0
#
# Review: enak lain kali beli lagi trimakasih gan
# Predicted Label: 1
#
# Review: saat diterima keripik byk yg sudah hancur yah mungkin dri ekspedisinya
# Predicted Label: 1
#
# Review: respon cepat barang mulus sesuai deskripsi thx ya
# Predicted Label: 1
#
# Review: wow yum yum enak
# Predicted Label: 1
#
# Review: cheese cake nya enak
# Predicted Label: 1
#
# Review: pengiriman cepat padahal di peak season rasa semoga enak kirim tuk hadiah
# Predicted Label: 1
#
# Review: good product trusted seller
# Predicted Label: 1
#
# Review: barang kondisi bagus rasanya enak seller fast respon packing rapi dan aman rekomen
# Predicted Label: 1
#
# Review: pas sesuai selera
# Predicted Label: 1
#
# Review: pesanan saya sesuai kalau dilihat tingkat kematangan dah pas buat saya wangi kuenya juga enak banget apalagi dimakan siippdehh overall bagus
# Predicted Label: 1
#
# Review: untuk kacangnya agak ancur yg lain bagus
# Predicted Label: 1
#
# Review: pembelian yg ke 3 kali sudah langganan juga dgn jus ini kental n fresh jusnya
# Predicted Label: 1
#
# Review: amaaan sampenya paslah produk masih segel exp masih lama sukses yaa
# Predicted Label: 1
#
# Review: udah dtg thx y
# Predicted Label: 1
#
# Review: enak manis alami dari bahan
# Predicted Label: 1
#
# Review: ok banyak isinya cm mgkn krn pinggir dan tipis2 jd rasanya krg moist lbh suka lapis sby nya
# Predicted Label: 1
#
# Review: rekomended seller kerupuk enak sekali
# Predicted Label: 1
#
# Review: makasih barang sudah sampe dan sesuai pesanan
# Predicted Label: 1
#
# Review: enak sesuai gambar seller nya baik dan responsif dikasih bonus jg makasih yaaa
# Predicted Label: 1
#
# Review: terima kasih produknya bagus ditambah pelayanannya yang baik barakallah fiik
# Predicted Label: 1
#
# Review: byk sampah nya mesti di pilihin pelan2 lg
# Predicted Label: 1
#
# Review: pengiriman cepat dan seller sangat responsif
# Predicted Label: 1
#
# Review: dikirim tepat waktu
# Predicted Label: 1
#
# Review: brg sdh ditrm bagus trmksh ya
# Predicted Label: 1
#
# Review: puas banget belanja disini barang cepat sampai sesuai gambar oke bgt deh pokok nya
# Predicted Label: 1
#
# Review: packing rapi produk original mantabss
# Predicted Label: 1
#
# Review: ini bukan baby cumi kapok beli disini gak sesuai diskripsi
# Predicted Label: 1
#
# Review: udah langganan recommended seller
# Predicted Label: 1
#
# Review: Yaah tempatnya mayan luas, tidak cocok untuk yg mau ngerjain tugas di tempat yang agak tenang. Karena kadang berisik kendaraan. Untuk harga minumannya, lumayan terjangkau.
# Predicted Label: 1
#
# Review: sasuai
# Predicted Label: 1
#
# Review: bawangnya lebih bagus liat langsung drpd di fotonya
# Predicted Label: 1
#
# Review: packing bagus seller ramah hny sj untuk rasa yg ikan asinnya sy lbh sk yg bulu ayam hehe
# Predicted Label: 1
#
# Review: mantap pol
# Predicted Label: 1
#
# Review: respon seller cepat pengiriman cepat packing oke aman expired date nya jg msh lama tks yaa
# Predicted Label: 1
#
# Review: sudah sampai sesuai pesanan moga2 gak terlalu pedas
# Predicted Label: 1
#
# Review: puas banget sdh repeat order bolak balik selalu memuaskan packingnya itu yg top dikasih bubble wrap per brg thank u seller sukses selalu ya
# Predicted Label: 1
#
# Review: produk bagus sesuai selera harga bagus kurir lancar sesuai jadwal ini sdh pesanan yg keempat kali terimakasih sabina food
# Predicted Label: 1
#
# Review: penjual ramah dan cepat respon brg juga bagus dan harga lbh murah dari toko lain
# Predicted Label: 1
#
# Review: rasa boleh diadu
# Predicted Label: 1
#
# Review: enak kacangnya empuk lumayan oke juga dengan harga yang masih terjangkau
# Predicted Label: 1
#
# Review: pengiriman cepat packing rapi recomended
# Predicted Label: 1
#
# Review: rasanya utk mkaroni goreng merk ini memang memuaskan
# Predicted Label: 1
#
# Review: benar mede jumbo ini
# Predicted Label: 1
#
# Review: pedesnya banget
# Predicted Label: 1
#
# Review: thank u gan enak
# Predicted Label: 1
#
# Review: barang sudah diterima
# Predicted Label: 1
#
# Review: pengirimannya cepat jam 10 30 sudah sampai di rumah cake nya juga aman tidak hancur thanks
# Predicted Label: 1
#
# Review: wenaak
# Predicted Label: 1
#
# Review: pertama kalinya nyobain jamon biasa langganan hearty potion nya mnrt saya scr rasa dominan lemon dan madunya jadinya saya minumnya abis buka puasa utk ngehindarin maag utk sahur saya minum hearty potion
# Predicted Label: 1
#
# Review: pagi2 sdh sampai dan packing utuh bagus tks ya
# Predicted Label: 1
#
# Review: enak rasanya crispy
# Predicted Label: 1
#
# Review: mantap lahh thanks
# Predicted Label: 1
#
# Review: ok
# Predicted Label: 1
#
# Review: Nice place. Tempat nya gampang di tempuh dan tidak berada di kawasan macet. Arsitektur nya simple namun cozy. Pelayanan nya ramah dan cepat tanggap. Signature chicken nya enak. They also over some service for your order. Di depan nya ada tempat karaoke nya juga. Parkiran luas dan space tempat nya pun tidak terlalu crowded.
# Predicted Label: 1
#
# Review: repeat order lumpia nya enak cocok dan delivery cepat admin nya ramah
# Predicted Label: 1
#
# Review: bentuk mentah kira2 4cm
# Predicted Label: 1
#
# Review: selain saya sengaja gunakan kotak kalau dilihat dari packaging bubble wrap juga lumayan tebal akan tetapi kenapa produknya di dalam bisa terbelah dan tidak hanya satu tapi keduanya padahal kotaknya baik baik saja jadi ragu akan higienisnya kalau seandainya memang dari awal sebelum packaging sudah seperti ini keadaannya yaitu terbelah terbuka dgn kondisi plastiknya pecah besar kemungkinannya di bagian terbuka tersebut bisa terkontaminasi sesuatu not recommended sudah ikuti saran anda buat chat tapi jangankan anda respon sengaja niat untuk dibaca saja enggak dari 22 feb s d hari ini 4 maret 2021 jadi jangan cuma buat modus seolah kalian perduli dilihat buyer atau calon buyer lain di jawaban review saya ini padahal gak ada itikad baiknya sama sekali kalau kalian merasa diuntungkan oleh review yang baik jangan dijadikan pembenaran untuk seperti ini saya beli hanya dua dan sengaja pilih pakai kotak supaya terjamin kualitasnya jangan kalian pikir cuma nilai transaksinya 35 ribu konsumen gak akan komplain saya juga gak minta uang balik tapi minta penjelasan yang jujur transparan bukan ngomong doang
# Predicted Label: 0
#
# Review: all is good
# Predicted Label: 1
#
# Review: mantap pengiriman cepat packingan aman
# Predicted Label: 1
#
# Review: Lantai 2 nya kotor dan sangat tidak tertata. Harusnya jadi kesadaran bagi pengunjung juga untuk membuang sampah sisa ke tempat sampah dan merapikan tempat duduknya agar pengunjung setelahnya bisa merasa nyaman
# Predicted Label: 0
#
# Review: cepet banget nyampenya dari bdg ke bekasi rasanya asli dan fresh udah kaya abis meras lemon sendiri mudah2an bisa dipertahankan kualitasnya
# Predicted Label: 1
#
# Review: pengiriman cepat n produk blom di coba
# Predicted Label: 1
#
# Review: cepat quick respon ikannya mantul utuh semua belum saya buka tapi bau asapnya sudah tercium
# Predicted Label: 1
#
# Review: asinan terfav
# Predicted Label: 1
#
# Review: cantik sprinkle nya thank you
# Predicted Label: 1
#
# Review: like usual special bu rudy
# Predicted Label: 1
#
# Review: enaakk
# Predicted Label: 1
#
# Review: paking rapih fast respon pengiriman cepat sukses sll
# Predicted Label: 1
#
# Review: seperti biasa mantap
# Predicted Label: 1
#
# Review: sekarang ga perlu lg hrs ke padang klo pengen keripik baladonya cukup di tokopedia aja 2 hari sdh sampai jkt terima kasih serley dan toko pedia
# Predicted Label: 1
#
# Review: orderan kedua dari toko ini mantap
# Predicted Label: 1
#
# Review: dah langganan rasa konsisten
# Predicted Label: 1
#
# Review: expired nya masih panjang 2022
# Predicted Label: 1
#
# Review: beli ini untuk teman di luar kota pengemasan dan pengirimannya cepat banget thank you seller
# Predicted Label: 1
#
# Review: mantap barang sudah sampai
# Predicted Label: 1
#
# Review: toilet dicampur dengan tempat pembuangan sisa makanan, setiap sudut ditempat ini penuh minyak, tempat kurang bersih sih menurutku trs panas juga, alat makan belum dikeringkan dan menurut saya itu sesuatu yang kurang enak dilihat, saya juga harus menunggu pelayan untuk mengambil alat makan karena kosong
# Predicted Label: 0
#
# Review: mantul selalu beli yang ini meski panas perut ge
# Predicted Label: 1
#
# Review: te o pe te o pe te o pe thanks seller
# Predicted Label: 1
#
# Review: Tempatnya asik nyaman. Kalo sore atau malam enak diluar lumayan sejuk. Layanan ramah cepat, makanan enak sesuai yang saya pesan iga barbeque empuk bumbu meresap & potato wedges nya enak lembut walau garing diluar, croissant, salad enak.
# Predicted Label: 1
#
# Review: enak banget rasanya pas
# Predicted Label: 1
#
# Review: pengiriman cepat packing rapi rekomended seller thanks
# Predicted Label: 1
#
# Review: fast respon rasanya juga enak pengemasannya juga menggunakan double wrapping terima kasih yaaa
# Predicted Label: 1
#
# Review: packingnya aman bagus
# Predicted Label: 1
#
# Review: bumbu kemanisan ini bukan kimchi bumbunya jauh bgt
# Predicted Label: 1
#
# Review: packing rapih dan aman
# Predicted Label: 1
#
# Review: barang di terima baik rasa tdk berubah walaupun di kirim ke luar kota
# Predicted Label: 1
#
# Review: enak rasanya pas gak repot langsung makan bt lebaran mau order lg thx u
# Predicted Label: 1
#
# Review: sudah sering order pelayanan pengiriman dan produk baik
# Predicted Label: 1
#
# Review: joss gandos
# Predicted Label: 1
#
# Review: alhamdulillah sudah sampe dengan selamat
# Predicted Label: 1
#
# Review: barang ori bagus pengiriman cepat banget sippp
# Predicted Label: 1
#
# Review: baru tau ada di tokopedia langsung order kerennnnn banget deh order tgl 4 tengah malem di respon sama adminnya tgl 5 dikirim dan barusan nyampe tgl 6 ini mah masuknya sehari aja padahal semarang depok packing rapih bangettt mochi aman ga berantakan untuk rasa yah udh terkenal enak dari dulu makasi moachi gemini sukses terus
# Predicted Label: 1
#
# Review: renyah empuk aroma bumbu segar pengiriman rapi terima kasih
# Predicted Label: 1
#
# Review: biar bintang yg berbicara hehehe pokoo nya puas
# Predicted Label: 1
#
# Review: kiriman cepat sampai hanya kuacinya nempel di kulit luar
# Predicted Label: 1
#
# Review: puas belanja disini produk bagus packing aman
# Predicted Label: 1
#
# Review: emang bener bener nagihin dikirimnya juga pake kardus dan bubble wrap tebal
# Predicted Label: 1
#
# Review: nanasnya manis banget cuttingnya juga rapi suka banget puas banget
# Predicted Label: 1
#
# Review: saya tidak ada masalah dengan kualitas barangnya yang membuat saya kecewa adalah alur kerja dari tokocabang yang tidak bisa membatalkan pesanan sesuai penjelasan admin udah gitu adminnya sendiri jarang baca chat padahal sering online seharusnya 1 kalau memang tokocabang tidak bisa membatalkan pesanan harus ada notifikasi khusus di tokopedianya 2 admin harap lebih sering merespon chat terutama jika ada kasus2 seperti ini gimana kalau pesanan harus batal karena alamatnya salah apa iya tidak bisa dibatalkan juga kok jadi ribet ya dengan adanya tokocabang
# Predicted Label: 0
#
# Review: keren kirim ke bandung cepat sampai nya terima kasih ya
# Predicted Label: 1
#
# Review: pengiriman super cepat seller fast respond sdh bbrp kali order recommended seller
# Predicted Label: 1
#
# Review: rasanya tetap segar
# Predicted Label: 1
#
# Review: terimakasih anak saya suka sekali
# Predicted Label: 1
#
# Review: yummiest
# Predicted Label: 1
#
# Review: ok sangat puaas thankssss
# Predicted Label: 1
#
# Review: packing super baik di bungkus plastik 2 kali lalu di wrap dgn lakban dgn super rapi respon penjual cepat terimakasih
# Predicted Label: 1
#
# Review: beli untuk yang kesekian kalinya mantap
# Predicted Label: 1
#
# Review: dendeng sapi nya sesuai dengan pesanan
# Predicted Label: 1
#
# Review: pokoke mantap lah ud bbrp x beli disini okk bgt deh
# Predicted Label: 1
#
# Review: parah enak banget gangerti lagi sea saltnya itu lovs bgttt
# Predicted Label: 1
#
# Review: barang sudah tiba terima kasih
# Predicted Label: 1
#
# Review: fast response n delivery thanks
# Predicted Label: 1
#
# Review: fast respon seller and kirim seller super ramah dan di monitor juga proses kirimnya lemon masih terlihat segar
# Predicted Label: 1
#
# Review: saya repurchase tapi kenapa bumbunya dipisah belom dicampurin kayak dulu pertama kali beli saya sedih paket belom saya buka sangking ssdihnya
# Predicted Label: 0
#
# Review: udah kesekian kali pesen dimari digorngnya gampil
# Predicted Label: 1
#
# Review: barang ok pengiriman ok
# Predicted Label: 1
#
# Review: sellernya bisa diajak gercep saat urgent exp masih lama thanks kak
# Predicted Label: 1
#
# Review: sejujurnya tidak seenak pembelian pertama saya juga ngga bisa pinpoint kenapa begitu tetapi cukup lumayan baik dr segi rasa maupun sambal yg lumayan nendang dan pedas
# Predicted Label: 1
#
# Review: mmg sudah biasa pake merk ini enak renyah gurih
# Predicted Label: 1
#
# Review: cepat rasanya cocok dilidah
# Predicted Label: 1
#
# Review: pengiriman cepat sameday respon penjual cepat dan rasanya enak banget makasih kak
# Predicted Label: 1
#
# Review: rasanya yummy mengenyangkan segar dengan manis yg pas ga too much pasti akan repeat order thanks
# Predicted Label: 1
#
# Review: packing superrrr rapi banget dan rasanya enaak bgt seller ramah baik sekali recommend yaaa
# Predicted Label: 1
#
# Review: enaknya pas tapi favorit egg dan lemonnya
# Predicted Label: 1
#
# Review: mantaplah rasanya respon sellernya cepat pengiriman super cepat 1 hari sampai dari semarang ke tangerang
# Predicted Label: 1
#
# Review: fast delivery good product
# Predicted Label: 1
#
# Review: penataannya rapih dan menarik garnishnya kreatif ada bunga cabe dan tulisan dari wortel untuk rasa enak wangi dan gurih rasa lauk pauknya juga pas
# Predicted Label: 1
#
# Review: teksturnya lembut semoga tidak gampang patah
# Predicted Label: 1
#
# Review: Saya senang makan di sini karena harganya murah, makanannya enak dan mengenyangkan.  Pilihan dagingnya jg banyak. Dr awal sdh di info waktunya 90 menit. Karena emang itu rule nya dan banyak yang ngantri mau makan juga. Biasanya kami belom 90 menit jg sdh kelar makannya. Juga ada stamp kalo beli 10 dpt 1 gratis..
# Predicted Label: 0
#
# Review: proses cepat tp pake kurirnya lama
# Predicted Label: 1
#
# Review: campur ap aj enak
# Predicted Label: 1
#
# Review: ternyata 1 pc 1 kg
# Predicted Label: 1
#
# Review: ok mksih
# Predicted Label: 1
#
# Review: paket telah sampai packing oke kurir oke produk oke semoga kue bolu talasnya berkah
# Predicted Label: 1
#
# Review: wenak tenan
# Predicted Label: 1
#
# Review: Tempat yang sangat unik karena berada dilantai atas toko petshop dengan memiliki lahan parkir yang sedikit untuk kendaraan roda empat, untuk kebersihan didalam sangat bersih, cita rasa yang cukup enak dan beragam jenisnya dengan harga uang sangat ramah dikantong, dan pelayanan dari pegawai ramah dan sangat sigap.
# Predicted Label: 1
#
# Review: selalu puas mohon dipertahankan ya
# Predicted Label: 1
#
# Review: parah udah repeat order ke 2 dan pesen lebih banyak ternyata enak banget ini
# Predicted Label: 1
#
# Review: mantap enak renyah
# Predicted Label: 1
#
# Review: rasanya enak dan sampai dengan aman pakai gojek sameday
# Predicted Label: 1
#
# Review: y
# Predicted Label: 1
#
# Review: mantap seperti biasa sukses selalu pempek metro
# Predicted Label: 1
#
# Review: barang sdh terima makasih
# Predicted Label: 1
#
# Review: dua2nya pecah chat seller katanya mau diganti tp ditunggu sampai hari ini gak ada padahal ud langganan disini klo pas sincia
# Predicted Label: 0
#
# Review: terimakasih moga makin laris toko nya
# Predicted Label: 1
#
# Review: udah langganan respon dan pengiriman cepat selalu dapat produk yg terbaik
# Predicted Label: 1
#
# Review: bawangnya enak sudah repeat order
# Predicted Label: 1
#
# Review: rasanya kok beda ya
# Predicted Label: 1
#
# Review: cocok semuanya thx ya
# Predicted Label: 1
#
# Review: bersih tanpa biji
# Predicted Label: 1
#
# Review: kualitasnya mantap penjualnya gercep dan packingnya rapih bin mantap
# Predicted Label: 1
#
# Review: top sellernya pesan langsung diproses kirim super cepat packing aman dan cuminya bagusss cakepp serasa ingin langsung dimasak beli lagi nanti di sini d terima kasih sukses selalu
# Predicted Label: 1
#
# Review: cepet banget ngirimnya order malam pagi udah datang rasanya juga enakm pedesnya pas ga asem juga ending ga pahit suka bisa buat campuran masakan ataupun camilan
# Predicted Label: 1
#
# Review: produk orisinil barang bagus service paling keren
# Predicted Label: 1
#
# Review: Pelayananannya ramah2 banget...cozy tempatnya dan bersih
# Predicted Label: 1
#
# Review: super fresh super laikkk 3
# Predicted Label: 1
#
# Review: seperti biasa paket terkirim dengan cepat rasa kacang enak mantap
# Predicted Label: 1
#
# Review: pembelian yg ke tiga kalinya bawangnya enak
# Predicted Label: 1
#
# Review: manisnya bikin enek
# Predicted Label: 1
#
# Review: enakk seger pengiriman super safety pake dus tebal n bubblewrap tebal jg
# Predicted Label: 1
#
# Review: pelayanan dan pengiriman slalu cepat terima kasih
# Predicted Label: 1
#
# Review: fast respond service ramah dan cepat barang makanan dikemas rapi dan tidak rapuh
# Predicted Label: 1
#
# Review: krispi
# Predicted Label: 1
#
# Review: sepertinya kemasan kurang cocok utk pengiriman same day isinya jadi ikut tertekan2
# Predicted Label: 1
#
# Review: renyah banget ngga gagal rasanya pas mantap
# Predicted Label: 1
#
# Review: pesanan diproses cepat pengiriman juga oke cepat sampai sesuai deskripsi dan langsung santap
# Predicted Label: 1
#
# Review: harga murah ed masih panjang
# Predicted Label: 1
#
# Review: packagingnya rapih banget
# Predicted Label: 1
#
# Review: pelayanan oke bangey kurnya sampe rumah dengan selamat
# Predicted Label: 1
#
# Review: recomended belanja barang disini
# Predicted Label: 1
#
# Review: response seller cepat tapi anteraja sebagai pembawa barang sangat lambat 6 hari baru sampe tokopedia harus mengevaluasi anteraja
# Predicted Label: 1
#
# Review: enak dan pengiriman cepat langsung habis ama anak2
# Predicted Label: 1
#
# Review: toko langganan kopi enak harga murah tapi pembelian kali ini agak lama di pengemasan ya beli tgl 12 baru dikirim tgl 15 lain kali mohon ditingkatkan kecepatan pelayanannya
# Predicted Label: 1
#
# Review: mantab packing rapi sesuai deskripsi dan fast response seller recommended thank you and success
# Predicted Label: 1
#
# Review: makananya enak
# Predicted Label: 1
#
# Review: rasanya kaya ada tepung ngga full bawang tapi lumayan lagi promo
# Predicted Label: 0
#
# Review: murah banget pengiriman dan respond cepat thanks
# Predicted Label: 1
#
# Review: rasa dan kualitas memuaskan pengiriman cepat
# Predicted Label: 1
#
# Review: sdh dibuat bergembira makasih gan
# Predicted Label: 1
#
# Review: produk sesuai dengan deskripsi dan dipaket dgn rapi
# Predicted Label: 1
#
# Review: pengiriman cepat tapi barang sampai ada satu kemasan yg terbuka jadi isinya berantakan
# Predicted Label: 0
#
# Review: rasa nya itu loh ngangenin mantab
# Predicted Label: 1
#
# Review: mantap bro repeat order
# Predicted Label: 1
#
# Review: enak mede nyaaa
# Predicted Label: 1
#
# Review: wah dapet free biskuit terimakasih
# Predicted Label: 1
#
# Review: saladnya cantik bentuknya tapi aku tidak suka dressingnya rasa seperti ada wasabi untungnya beli dressing pesto jd bisa dimakan pake pesto tq
# Predicted Label: 0
#
# Review: enaaaak bangeeettt lembuutt nanasnya gak pelit lagi kasih nya mau pesen ahh buat lebaran
# Predicted Label: 1
#
# Review: udah langganan beli disini selalu puas dgn produknya harga bersaing thanks
# Predicted Label: 1
#
# Review: terlalu enak diatas ekspektasi pasti beli lagi utamanya yang vanilla jadi rebutan
# Predicted Label: 1
#
# Review: wah sellernya fast respon barang juga dipacking aman pokoknya mantap deh
# Predicted Label: 1
#
# Review: fast response barang bagus good job
# Predicted Label: 1
#
# Review: bubuk coklanya bagus dan sesuai pesanan good
# Predicted Label: 1
#
# Review: terima kasih produk dan service mantap biar bintang yg berbicara
# Predicted Label: 1
#
# Review: langganan terus dr anak pertama
# Predicted Label: 1
#
# Review: produk diterima kondisi hancur
# Predicted Label: 1
#
# Review: asik dapat bonus juga gula putih 2 bungkus
# Predicted Label: 1
#
# Review: sudah kesekian kalinya pesen disini gak pernah kecewa
# Predicted Label: 1
#
# Review: kwalitasnya mantul2
# Predicted Label: 1
#
# Review: sampai dengan baik saya kemas di toples untuk di jual lagi terimakasih
# Predicted Label: 1
#
# Review: mantap renyah next order lagi
# Predicted Label: 1
#
# Review: enak kopinya and tempatnya bagus good job sir
# Predicted Label: 1
#
# Review: sesuai order
# Predicted Label: 1
#
# Review: respon toko ok kurir lelet sameday 12jam
# Predicted Label: 1
#
# Review: enak banget cakenya fluppy super moiss bgt
# Predicted Label: 1
#
# Review: pokonya pelayanannya cakeep banget deeh jadi langganan
# Predicted Label: 1
#
# Review: Semuanya Ok, rasa, tempat dan pelayanannya.
# Predicted Label: 1
#
# Review: pengiriman cepat seller fast respon produk kw baik
# Predicted Label: 1
#
# Review: pengiriman cepat packing lumayan mungkin karena pinggiran kue sedikit gosong rasanya sedikit pahit saya tidak menemukan beli 3 gratis 1 yg saya terima cuma 3 tp overall good lah
# Predicted Label: 0
#
# Review: pengiriman cepat thx ya
# Predicted Label: 1
#
# Review: ikan sudah diterima fresh langsung diolah mangut ikan pari asap mantabz rekomended
# Predicted Label: 1
#
# Review: seger and fres bngt makasihhhhh
# Predicted Label: 1
#
# Review: respon penjual cepat dan paket rapi barang sesuai dengan deskripsi produk enak terima kasih
# Predicted Label: 1
#
# Review: enak banget sdh ky makan di resto korea
# Predicted Label: 1
#
# Review: siang order sore langsung sampai
# Predicted Label: 1
#
# Review: karena ini buat temen aku jadi ga punya fotonya alhamdulillah temen aku suka
# Predicted Label: 1
#
# Review: sudah kesekian x nya beli di toko ini memuaskan fast respon pesan langsung di proses pengemasan rapih top begete lakh pokonamah
# Predicted Label: 1
#
# Review: udh coba berbagai macam merk tp ny melinda yg paling enak the best bawang goreng in town
# Predicted Label: 1
#
# Review: pembelian yg kesekian ribu kaliiii
# Predicted Label: 1
#
# Review: respon n pengiriman cepat sudah minum botol yg ke 2 tp hasil blom seberapa kelihatan berat badan hanya turun 1 2kg
# Predicted Label: 1
#
# Review: mantap masih fresh trima kasih pak kurir dan juga trima kasih buat tokonya semoga makin sukses
# Predicted Label: 1
#
# Review: enak dan unik mantap lah
# Predicted Label: 1
#
# Review: pengiriman cepat dan packing rapih
# Predicted Label: 1
#
# Review: pesan mendadak karena opor masih sisa banyak order cepat di respons dan rasa enak lontong lembut terima kasih
# Predicted Label: 1
#
# Review: pengiriman sangat cpt product blm dicoba blm bisa review product
# Predicted Label: 1
#
# Review: jadi langganan setia deh
# Predicted Label: 1
#
# Review: maaanstaabb gaaannn
# Predicted Label: 1
#
# Review: produk bagus siomay enak penjual sangat responsif terima kasih ya
# Predicted Label: 1
#
# Review: Mantap, tempat nya bersih dan nyaman. Banyak pilihan nya pula.
# Predicted Label: 1
#
# Review: kimchinya enakkkk banget kyk yg ada di korean food resto dan fresh
# Predicted Label: 1
#
# Review: langganan terpercaya luar biasa
# Predicted Label: 1
#
# Review: pengiriman cepat packing rapi barang ori
# Predicted Label: 1
#
# Review: aman
# Predicted Label: 1
#
# Review: barang sdh diterima sesuai pesanan packing aman berat tdk ngecek sesuai ato tdk blm dicoba semoga enak pengiriman cepat
# Predicted Label: 1
#
# Review: kemasan rapih dan bersih kerupuk utuh bagus
# Predicted Label: 1
#
# Review: barang sesuai pesanan rekomended bnget pokok nya
# Predicted Label: 1
#
# Review: cheesecake nya abis diganti sama regal chocolate kuenya enak mksh fsnya
# Predicted Label: 1
#
# Review: pembelian ke 3x enak sih kerupuknya
# Predicted Label: 1
#
# Review: order bareng produk lainnya jadi 3 box di kemas dalam paper bag alhamdulillah aman saat diterima rasanya juara banget sea saltnya bikin sensasi yang akhir yang asik bgt
# Predicted Label: 1
#
# Review: pengiriman 3 hari packingan aman pakai kardus dan dibungkus bubble wrap produk overall ok ga pedas juga thank you
# Predicted Label: 1
#
# Review: Driver disuruh nunggu di basement yang panas, gerah. Mana proses makanannya lama. sedih. sekarang resto pada belagu.
# Predicted Label: 1
#
# Review: permennya enakkk makasih gan
# Predicted Label: 1
#
# Review: kurang enak ya tidak seperti yg dijual di bandung
# Predicted Label: 1
#
# Review: lazis
# Predicted Label: 1
#
# Review: enak bangettt ngett emping nya beli di tempat lain ga ada yg seenak ini
# Predicted Label: 1
#
# Review: muntep polll i love you
# Predicted Label: 1
#
# Review: barang oke packing rapih penjual responsif
# Predicted Label: 1
#
# Review: ahhh sukaaa packagingnya menggemaskan pengiriman juga cepat gak malu2in kalau buat kirim2 hampers
# Predicted Label: 1
#
# Review: seller nya good respon fast delivery padahal aku pake yg bebas ongkir pesen tgl 15 sampe 18 dr denpasar ke bekasi produk sudah pasti okeh makasih yaaaa
# Predicted Label: 1
